# %% [markdown]
# <a href="https://colab.research.google.com/github/youusef51/ANN/blob/main/ANN_LAB_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 17, 28],
    'City': ['New york', 'San francisco', 'Los anglos', 'Alex'],
    'Salary': [100, 150, 200, 300],
}

df = pd.DataFrame(data)
df
# Out:
#       Name  Age           City  Salary
# 0    Alice   25       New york     100
# 1      Bob   30  San francisco     150
# 2  Charlie   17     Los anglos     200
# 3    David   28           Alex     300

# %%
df[['Name','Salary']]
# Out:
#       Name  Salary
# 0    Alice     100
# 1      Bob     150
# 2  Charlie     200
# 3    David     300

# %%
df.iloc[0]
# Out:
# Name         Alice
# Age             25
# City      New york
# Salary         100
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# Name                Bob
# Age                  30
# City      San francisco
# Salary              150
# Name: 1, dtype: object

# %%
#calculate some statistics on each coulmn
df['Age'].mean()
# Out:
# 25.0

# %%
print("The minimum age is", df['Age'].min())
print("The maximum age is", df['Age'].max())
print("The mean age is", df['Age'].mean())
# Out:
# The minimum age is 17
# The maximum age is 30
# The mean age is 25.0

# %%
ndata = [10, 20, 30, 40, 50]
s= pd.Series(ndata)
print(s.min())
print(s.max())
print(s.mean())
# Out:
# 10
# 50
# 30.0

# %%
df
# Out:
#       Name  Age           City  Salary
# 0    Alice   25       New york     100
# 1      Bob   30  San francisco     150
# 2  Charlie   17     Los anglos     200
# 3    David   28           Alex     300

# %%
df.head()
# Out:
#       Name  Age           City  Salary
# 0    Alice   25       New york     100
# 1      Bob   30  San francisco     150
# 2  Charlie   17     Los anglos     200
# 3    David   28           Alex     300

# %%
df.tail(2)
# Out:
#       Name  Age        City  Salary
# 2  Charlie   17  Los anglos     200
# 3    David   28        Alex     300

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   City    4 non-null      object
#  3   Salary  4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 256.0+ bytes

# %%
df.describe()
# Out:
#              Age      Salary
# count   4.000000    4.000000
# mean   25.000000  187.500000
# std     5.715476   85.391256
# min    17.000000  100.000000
# 25%    23.000000  137.500000
# 50%    26.500000  175.000000
# 75%    28.500000  225.000000
# max    30.000000  300.000000

# %%
df.describe().T
# Out:
#         count   mean        std    min    25%    50%    75%    max
# Age       4.0   25.0   5.715476   17.0   23.0   26.5   28.5   30.0
# Salary    4.0  187.5  85.391256  100.0  137.5  175.0  225.0  300.0

# %%
df
# Out:
#       Name  Age           City  Salary
# 0    Alice   25       New york     100
# 1      Bob   30  San francisco     150
# 2  Charlie   17     Los anglos     200
# 3    David   28           Alex     300

# %%
# Assuming you have two DataFrames: df1 and df2
merged_df = pd.merge(df, df, on='Name')
merged_df
# Out:
#       Name  Age_x         City_x  Salary_x  Age_y         City_y  Salary_y
# 0    Alice     25       New york       100     25       New york       100
# 1      Bob     30  San francisco       150     30  San francisco       150
# 2  Charlie     17     Los anglos       200     17     Los anglos       200
# 3    David     28           Alex       300     28           Alex       300

# %%
df['New_Salary'] = df['Salary'].apply(lambda x: x + 30)
df
# Out:
#       Name  Age           City  Salary  New_Salary
# 0    Alice   25       New york     100         130
# 1      Bob   30  San francisco     150         180
# 2  Charlie   17     Los anglos     200         230
# 3    David   28           Alex     300         330

# %%
sorted_df = df.sort_values(by='New_Salary')
sorted_df
# Out:
#       Name  Age           City  Salary  New_Salary
# 0    Alice   25       New york     100         130
# 1      Bob   30  San francisco     150         180
# 2  Charlie   17     Los anglos     200         230
# 3    David   28           Alex     300         330

# %%
sorted_df = df.sort_values(by='Age')
sorted_df
# Out:
#       Name  Age           City  Salary  New_Salary
# 2  Charlie   17     Los anglos     200         230
# 0    Alice   25       New york     100         130
# 3    David   28           Alex     300         330
# 1      Bob   30  San francisco     150         180

# %%
df['is_adult'] = df['Age'].apply(lambda x: True if x >= 18 else False)
df
# Out:
#       Name  Age           City  Salary  New_Salary  is_adult
# 0    Alice   25       New york     100         130      True
# 1      Bob   30  San francisco     150         180      True
# 2  Charlie   17     Los anglos     200         230     False
# 3    David   28           Alex     300         330      True

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City', 'Salary', 'New_Salary', 'is_adult'], dtype='object')

# %%
df.Name
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# Name: Name, dtype: object
